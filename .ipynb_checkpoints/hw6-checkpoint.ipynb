# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Ali\Documents\python\facebook_ads_data.csv")
df
# Out:
#          ad_date campaign_name  total_spend  total_impressions  total_clicks  \
# 0     2022-11-05     Expansion         0.00                  0             0
# 1     2022-11-01     Expansion         0.00                  0             0
# 2     2022-10-31     Expansion       227.45               6054            58
# 3     2022-10-30     Expansion       335.91              27562            69
# 4     2022-10-29     Expansion       714.03              33358           115
# ...          ...           ...          ...                ...           ...
# 1489  2020-11-15     Discounts         6.98              12465           657
# 1490  2020-11-14     Discounts         7.27               5005           392
# 1491  2020-11-13     Discounts         6.36              11669           451
# 1492  2020-11-12     Discounts        23.00              10473           397
# 1493  2020-11-11     Discounts         1.89               1800            45
#
# ...

# %%
# (Opsiyonel) tarih tipi:
# Tarih sütununu datetime formatına çevirme
df['ad_date'] = pd.to_datetime(df['ad_date'])
df.head()
# Out:
#      ad_date campaign_name  total_spend  total_impressions  total_clicks  \
# 0 2022-11-05     Expansion         0.00                  0             0
# 1 2022-11-01     Expansion         0.00                  0             0
# 2 2022-10-31     Expansion       227.45               6054            58
# 3 2022-10-30     Expansion       335.91              27562            69
# 4 2022-10-29     Expansion       714.03              33358           115
#
#    total_value   cpc    cpm       ctr      romi
# 0         0.00   NaN    NaN       NaN       NaN
# 1         0.00   NaN    NaN       NaN       NaN
# 2       191.87  3.92  37.57  0.009580  0.843570
# 3       472.61  4.87  12.19  0.002503  1.406954
# 4       680.34  6.21  21.41  0.003447  0.952817

# %% [markdown]
# <h3>1.Group the data by day and create two graphs for the grouped data:</h3>
#
# A graph of the total amount of advertising costs in 2021;
#
# Graph with daily ROMI in2021;
#
#
# Tip
#  You can compare and filter dates even without converting field values. For example, try comparing the ad_date value with the text 2022-01-;01
#
# B:onus Point Use the rolling() method to display a moving average of costs and R;OMI)

# %%
daily_stats = df.groupby('ad_date')[['total_spend', 'total_impressions', 'total_clicks', 'total_value']].sum()
daily_stats
# Out:
#             total_spend  total_impressions  total_clicks  total_value
# ad_date
# 2020-11-11         1.89               1800            45         2.38
# 2020-11-12        23.00              10473           397        21.13
# 2020-11-13         6.36              11669           451         9.77
# 2020-11-14         7.27               5005           392        12.67
# 2020-11-15         6.98              12465           657        10.96
# ...                 ...                ...           ...          ...
# 2022-10-29       714.03              33358           115       680.34
# 2022-10-30       335.91              27562            69       472.61
# 2022-10-31       227.45               6054            58       191.87
# 2022-11-01         0.00                  0             0         0.00
# 2022-11-05         0.00                  0             0         0.00
#
# [547 rows x 4 columns]

# %%
daily_stats['romi'] = daily_stats['total_value'] / daily_stats['total_spend']
daily_stats = daily_stats.reset_index()
daily_stats
# Out:
#        ad_date  total_spend  total_impressions  total_clicks  total_value  \
# 0   2020-11-11         1.89               1800            45         2.38
# 1   2020-11-12        23.00              10473           397        21.13
# 2   2020-11-13         6.36              11669           451         9.77
# 3   2020-11-14         7.27               5005           392        12.67
# 4   2020-11-15         6.98              12465           657        10.96
# ..         ...          ...                ...           ...          ...
# 542 2022-10-29       714.03              33358           115       680.34
# 543 2022-10-30       335.91              27562            69       472.61
# 544 2022-10-31       227.45               6054            58       191.87
# 545 2022-11-01         0.00                  0             0         0.00
# 546 2022-11-05         0.00                  0             0         0.00
#
#          romi
# 0    1.259259
# 1    0.918696
# 2    1.536164
# 3    1.742779
# ...

# %%
daily_stats_2021 = daily_stats[(daily_stats['ad_date'] >= '2021-01-01') & (daily_stats['ad_date'] <= '2021-12-31')]

# %%
daily_stats_2021
# Out:
#        ad_date  total_spend  total_impressions  total_clicks  total_value  \
# 48  2021-01-01         0.39                353             0         0.59
# 49  2021-01-02         7.74              10709           205         6.90
# 50  2021-01-04        70.06              22440          1256        68.47
# 51  2021-01-05        81.15              60232          1379        61.68
# 52  2021-01-06       142.77              65265           431       145.97
# ..         ...          ...                ...           ...          ...
# 372 2021-12-27       478.31             103725           504       686.47
# 373 2021-12-28       359.83             101788           499       450.47
# 374 2021-12-29       163.25              32290           435       171.76
# 375 2021-12-30       285.67              64171           984       330.26
# 376 2021-12-31       173.38              56749           281       183.11
#
#          romi
# 48   1.512821
# 49   0.891473
# 50   0.977305
# 51   0.760074
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5), dpi=100)

plt.plot(daily_stats_2021['ad_date'], daily_stats_2021['total_spend'].rolling(10).mean(), label='Total spend')

plt.legend()

plt.title('Facebook advertising costs in 2021')

plt.xlabel('Date')
plt.ylabel('Spend, $')

plt.xticks(list(daily_stats_2021['ad_date'])[::60])

plt.show()

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.plot(daily_stats_2021['ad_date'], daily_stats_2021['romi'].rolling(10).mean(), label='ROMI (10G MA)')

plt.legend()

plt.title('Facebook Advertising ROMI in 2021')

plt.xlabel('Date')
plt.ylabel('ROMI')

plt.xticks(list(daily_stats_2021['ad_date'])[::60])

plt.show()

# %%
# 2021 yılına filtreleme
df_2021 = df[(df["ad_date"] >= "2021-01-01") & (df["ad_date"] < "2022-01-01")].copy()

# Günlük toplam harcama
daily_spend = df_2021.groupby("ad_date")["total_spend"].sum()

# Günlük ROMI 
daily_romi = df_2021.groupby("ad_date")["romi"].mean()

daily_romi.head()
# Out:
# ad_date
# 2021-01-01    1.512821
# 2021-01-02    0.891473
# 2021-01-04    0.977305
# 2021-01-05    0.760074
# 2021-01-06    1.011212
# Name: romi, dtype: float64

# %%
#Günlük harcama ve günlük ROMI grafiği
plt.figure(figsize=(12, 5))
daily_spend.plot(title="2021 Günlük Reklam Harcamaları")
plt.ylabel("Toplam Harcama")
plt.show()

plt.figure(figsize=(12, 5))
daily_romi.plot(title="2021 Günlük ROMI")
plt.ylabel("ROMI")
plt.show()

# %% [markdown]
# <h3>2.Group the data by campaign name and create two graphs: </h3>
#
# A graph of the total amount of ad spend in each of the campaigns;
#
# Total ROMI in each of the campaigns.

# %%
campaign_stats = df.groupby('campaign_name')[['total_spend', 'total_value']].sum()
campaign_stats
# Out:
#                  total_spend  total_value
# campaign_name
# Brand                 539.92       670.15
# Crazy discounts      2175.29      2583.59
# Discounts            2856.39      3516.27
# Electronics         23920.42     29169.38
# Expansion           67212.82     83288.66
# Hobbies             11326.97     13974.63
# Lookalike           63631.09     80234.70
# New items            2936.97      3742.05
# Promos               4993.84      8793.77
# Trendy               1992.31      3798.90
# Wholesale           14181.71     17421.33

# %%
campaign_stats.shape
# Out:
# (11, 2)

# %%
campaign_stats['romi'] = campaign_stats['total_value'] / campaign_stats['total_spend']
campaign_stats = campaign_stats.reset_index()
campaign_stats
# Out:
#       campaign_name  total_spend  total_value      romi
# 0             Brand       539.92       670.15  1.241202
# 1   Crazy discounts      2175.29      2583.59  1.187699
# 2         Discounts      2856.39      3516.27  1.231019
# 3       Electronics     23920.42     29169.38  1.219434
# 4         Expansion     67212.82     83288.66  1.239178
# 5           Hobbies     11326.97     13974.63  1.233748
# 6         Lookalike     63631.09     80234.70  1.260935
# 7         New items      2936.97      3742.05  1.274119
# 8            Promos      4993.84      8793.77  1.760923
# 9            Trendy      1992.31      3798.90  1.906782
# 10        Wholesale     14181.71     17421.33  1.228436

# %%
campaign_stats.shape
# Out:
# (11, 4)

# %%
import seaborn as sns

sns.set_theme()

sns.barplot(x='total_spend', y='campaign_name', data=campaign_stats, color="b")
# Out:
# <Axes: xlabel='total_spend', ylabel='campaign_name'>

# %%
sns.barplot(x='romi', y='campaign_name', data=campaign_stats, color="b")
# Out:
# <Axes: xlabel='romi', ylabel='campaign_name'>

# %% [markdown]
# <h3>3.Use the box plot to determine the spread of daily ROMI in each campaign (by campaign name).</h3>

# %%
plt.figure(figsize=(15,5), dpi=100)

sns.boxplot(x="campaign_name", y="romi", data=df)
# Out:
# <Axes: xlabel='campaign_name', ylabel='romi'>

# %%
# İsteneni tam karşılamak için ROMI’yi kampanya+gün temelinde hesaplayıp sonra box plot çizin
# (tekil satır düzeyinde gürültü olabiliyor).
plt.figure(figsize=(15,5), dpi=100)
daily_campaign = (df.groupby(['campaign_name','ad_date'], as_index=False)
                    [['total_spend','total_value']].sum())
daily_campaign['romi'] = (
    (daily_campaign['total_value'] - daily_campaign['total_spend'])
    / daily_campaign['total_spend']
)
sns.boxplot(data=daily_campaign, x='campaign_name', y='romi')
# Out:
# <Axes: xlabel='campaign_name', ylabel='romi'>

# %% [markdown]
# <h3>4.Create a histogram with the distribution of ROMI values in the facebook_ads_data.csv table.</h3>

# %%
sns.displot(data=df, x="romi")
# Out:
# C:\Users\Ali\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['romi'] = (df['total_value'] - df['total_spend']) / df['total_spend']
sns.displot(data=df, x="romi")
# Out:
# C:\Users\Ali\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <h3>5.Draw a heatmap of the correlation between all the numerical values in the facebook_ads_data.csv table. Which values have the highest and lowest correlation? What does total_value correlate with?</h3>

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.0%', cmap= 'crest_r')
# Out:
# <Axes: >

# %%
#Korelasyon ısı grafiği
plt.figure(figsize=(10, 8))
corr = df.select_dtypes(include="number").corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Sayısal Göstergeler Arası Korelasyon")
plt.show()

# %% [markdown]
# <h3>6.Create a dot plot with linear regression (you can use the lmplot() function to do this) based on the data from total_spend and total_value to visualize the relationship between these values.</h3>

# %%
sns.lmplot(data=df, x="total_spend", y="total_value")
# Out:
# C:\Users\Ali\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df, x="total_spend", y="total_value", height=6, aspect=1.5)
plt.title("Harcamalar vs. Değer (Doğrusal Regresyon)")
plt.show()
# Out:
# C:\Users\Ali\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Günlük hareketli harcama ve ROMI
plt.figure(figsize=(12, 5))
daily_spend.rolling(window=7).mean().plot(title="7 Günlük Hareketli Ortalama Harcama")
plt.show()

plt.figure(figsize=(12, 5))
daily_romi.rolling(window=7).mean().plot(title="7 Günlük Hareketli Ortalama ROMI")
plt.show()

# %%
# Kampanya bazlı toplam harcama
campaign_spend = df.groupby("campaign_name")["total_spend"].sum()

# Kampanya bazlı ortalama ROMI
campaign_romi = df.groupby("campaign_name")["romi"].mean()

campaign_romi
# Out:
# campaign_name
# Brand              0.241293
# Crazy discounts    0.208851
# Discounts          0.247111
# Electronics        0.225274
# Expansion          0.237941
# Hobbies            0.238967
# Lookalike          0.245056
# New items          0.279135
# Promos             0.751932
# Trendy             0.840145
# Wholesale          0.239026
# Name: romi, dtype: float64

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(campaign_spend.index, campaign_spend.values, color='darkblue')
plt.xlabel("Kampanya Adı")
plt.ylabel("Toplam Harcama")
plt.title("Kampanya Bazlı Toplam Harcama")
plt.xticks(rotation=45)

# Barların üzerine değerleri yaz
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5,
             f"{height:.2f}", ha='center')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(campaign_romi.index, campaign_romi.values, color='lightgreen')
plt.xlabel("Kampanya Adı")
plt.ylabel("Ortalama ROMI")
plt.title("Kampanya Bazlı Ortalama ROMI")
plt.xticks(rotation=45)

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.01,
             f"{height:.2f}", ha='center')

plt.tight_layout()
plt.show()

# %%
#Kampanya bazlı romi dağılımı
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="campaign_name", y="romi")
plt.xticks(rotation=45)
plt.title("Kampanya Bazlı Günlük ROMI Dağılımı")
plt.show()

# %%
#ROMI histogram grafiği
plt.figure(figsize=(10, 5))
sns.histplot(df["romi"], bins=30, kde=True)
plt.title("ROMI Dağılımı")
plt.xlabel("ROMI")
plt.show()
